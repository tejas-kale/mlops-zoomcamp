# %% [markdown]
# # Homework 2
#
# In the second week's homework, the goal is to get familiar with MLflow.
#
# First, let us load the required packages.

# %%
import mlflow

# %% [markdown]
# ## Question 1: Install MLflow
#
# The installed MLflow version is `3.1.1`.

# %%
mlflow.__version__
# Out:
# '3.1.1'

# %% [markdown]
# ## Question 2: Download and preprocess data
#
# There were 4 files saved to the output folder.

# %%
# !python ./preprocess_data.py --raw_data_path ../data/green_taxi_2023 --dest_path ./output

# %% [markdown]
# ## Question 3: Train a model with autolog
#
# The value of `min_samples_split` is *2*. To enable autolog, a simple `mlflow.autolog()` call is sufficient without needing to explicitly start a run.

# %%
# !python ./train.py
# Out:
# 2025/07/05 20:47:31 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2025/07/05 20:47:31 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '2a2bd43c66fa4333963d74335d22b06e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2025/07/05 20:47:47 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.

# %% [markdown]
# ## Question 4: Launch the tracking server locally
#
# The other argument to pass is `default-artifact-root`.

# %%
#!mlflow server --backend-store-uri sqlite:///backend.db --default-artifact-root ./artifacts

# %% [markdown]
# ## Question 5: Tune model hyperparameters
#
# The best validation RMSE is `5.335`.

# %%
# !python ./hpo.py
# Out:
# /workspaces/mlops-zoomcamp/.venv/lib/python3.12/site-packages/hyperopt/atpe.py:19: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# 🏃 View run respected-midge-524 at: http://127.0.0.1:5000/#/experiments/1/runs/a4019c98984a4b01b1e0a3341a7d7a5b
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run bold-shoat-801 at: http://127.0.0.1:5000/#/experiments/1/runs/1865a4b036244cdb93fcf7e172bed3c3
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run unique-shoat-719 at: http://127.0.0.1:5000/#/experiments/1/runs/30a821196aa74f70be5c6a2aaad3f9ed
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run unruly-horse-879 at: http://127.0.0.1:5000/#/experiments/1/runs/d16fbe98321340a38b625dcf95b96415
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run indecisive-jay-35 at: http://127.0.0.1:5000/#/experiments/1/runs/e9a0253a871f4ee7b681d888412a71a6
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run invincible-crow-215 at: http://127.0.0.1:5000/#/experiments/1/runs/d9078c6c89ca4e5785d19b627578fc35
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run bedecked-duck-237 at: http://127.0.0.1:5000/#/experiments/1/runs/3ed5a8fb53c44d91b20cf144d7a85a96
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run debonair-skunk-575 at: http://127.0.0.1:5000/#/experiments/1/runs/e32b978bafd6429c9ceb35310d654548
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run secretive-wasp-968 at: http://127.0.0.1:5000/#/experiments/1/runs/76032305934a4a539a312f17141cb5bc
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run gifted-bass-431 at: http://127.0.0.1:5000/#/experiments/1/runs/6cfbe68142c64ccabb1563397584d7d2
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run brawny-rook-636 at: http://127.0.0.1:5000/#/experiments/1/runs/c85cc19f3f1c45d1b12fd1756d20078f
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run gaudy-owl-383 at: http://127.0.0.1:5000/#/experiments/1/runs/c879b783ae6d4e4cb20f88e7fccbcce0
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run sincere-wren-959 at: http://127.0.0.1:5000/#/experiments/1/runs/8fa95f7402744e54983b6b9f484aac5b
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run sincere-mink-495 at: http://127.0.0.1:5000/#/experiments/1/runs/c7ba55862a9a4eba885bae34258e457c
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 🏃 View run upbeat-donkey-578 at: http://127.0.0.1:5000/#/experiments/1/runs/22a47f43f85c44f5945d1ce3d3f8da2b
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
#
# 100%|██████████| 15/15 [01:06<00:00,  4.45s/trial, best loss: 5.335419588556921]

# %% [markdown]
# ## Question 6: Promote the best model to the model registry
#
# The test RMSE of the best model is `5.567`.

# %%
# !python ./register_model.py
# Out:
# 2025/07/05 21:11:38 INFO mlflow.tracking.fluent: Experiment with name 'random-forest-best-models' does not exist. Creating a new experiment.
# 2025/07/05 21:11:46 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 🏃 View run monumental-hare-538 at: http://127.0.0.1:5000/#/experiments/2/runs/38f2c5383e424365a3587d3fd9e569d2
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# 2025/07/05 21:12:01 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 🏃 View run bustling-fox-4 at: http://127.0.0.1:5000/#/experiments/2/runs/1224dd5692e7477ca81d75a42848e086
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# 2025/07/05 21:12:12 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 🏃 View run silent-duck-78 at: http://127.0.0.1:5000/#/experiments/2/runs/cc8436589be24449a44bfb1ff978b73e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# 2025/07/05 21:12:23 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 🏃 View run stylish-roo-25 at: http://127.0.0.1:5000/#/experiments/2/runs/6d68b709b9f74a68be5634513b567ff1
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# 2025/07/05 21:12:33 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 🏃 View run amusing-kite-201 at: http://127.0.0.1:5000/#/experiments/2/runs/0bc94e68ddee4d89b926b78a0ec2254b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# Successfully registered model 'nyc-taxi-duration-prediction'.
# 2025/07/05 21:12:36 WARNING mlflow.tracking._model_registry.fluent: Run with id 38f2c5383e424365a3587d3fd9e569d2 has no artifacts at artifact path 'model', registering model based on models:/m-b664994ff34b44b6a064796b3a6edd63 instead
# 2025/07/05 21:12:36 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: nyc-taxi-duration-prediction, version 1
# Created version '1' of model 'nyc-taxi-duration-prediction'.
